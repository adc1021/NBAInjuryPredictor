# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
injuryData = pd.read_csv("~/Documents/Job Search - 2023/NBA_Injury_Predictor/Injuries.csv")

# %%
injuryData.rename(columns={'Unnamed: 0': 'ID'}, inplace=True)

# %%
injuryData
# Out:
#           ID        Date       Team            Acquired    Relinquished
# 0          0  1951-12-25    Bullets                 NaN   Don Barksdale  \
# 1          1  1952-12-26     Knicks                 NaN   Max Zaslofsky
# 2          2  1956-12-29     Knicks                 NaN   Jim Baechtold
# 3          3  1959-01-16     Lakers                 NaN    Elgin Baylor
# 4          4  1961-11-26     Lakers                 NaN    Elgin Baylor
# ...      ...         ...        ...                 ...             ...
# 37662  37662  2023-04-16   Clippers       Marcus Morris             NaN
# 37663  37663  2023-04-16  Grizzlies       Dillon Brooks             NaN
# 37664  37664  2023-04-16  Grizzlies           Ja Morant             NaN
# 37665  37665  2023-04-16  Grizzlies   Jaren Jackson Jr.             NaN
# 37666  37666  2023-04-16  Grizzlies        Santi Aldama             NaN
#
#                                                    Notes
# 0                                           placed on IL
# 1                     placed on IL with torn side muscle
# 2                                placed on inactive list
# 3      player refused to play after being denied a ro...
# 4                      player reported for military duty
# ...                                                  ...
# 37662                                  activated from IL
# 37663                                  activated from IL
# 37664                                  activated from IL
# 37665                                  activated from IL
# 37666                                  activated from IL
#
# [37667 rows x 6 columns]

# %% [markdown]
# ### We want to separate the dataset by year to get a good idea of the total number of injuries that have occured annually

# %%
# Setting the objects in the column to a pandas datetime object
injuryData['Date'] = pd.to_datetime(injuryData['Date'])

#Grouping rows by 'decade' column
injuryData['Year'] = (injuryData['Date'].dt.year)

# %%
injuryData
# Out:
#           ID       Date       Team            Acquired    Relinquished
# 0          0 1951-12-25    Bullets                 NaN   Don Barksdale  \
# 1          1 1952-12-26     Knicks                 NaN   Max Zaslofsky
# 2          2 1956-12-29     Knicks                 NaN   Jim Baechtold
# 3          3 1959-01-16     Lakers                 NaN    Elgin Baylor
# 4          4 1961-11-26     Lakers                 NaN    Elgin Baylor
# ...      ...        ...        ...                 ...             ...
# 37662  37662 2023-04-16   Clippers       Marcus Morris             NaN
# 37663  37663 2023-04-16  Grizzlies       Dillon Brooks             NaN
# 37664  37664 2023-04-16  Grizzlies           Ja Morant             NaN
# 37665  37665 2023-04-16  Grizzlies   Jaren Jackson Jr.             NaN
# 37666  37666 2023-04-16  Grizzlies        Santi Aldama             NaN
#
#                                                    Notes  Year
# 0                                           placed on IL  1951
# 1                     placed on IL with torn side muscle  1952
# 2                                placed on inactive list  1956
# 3      player refused to play after being denied a ro...  1959
# 4                      player reported for military duty  1961
# ...                                                  ...   ...
# 37662                                  activated from IL  2023
# 37663                                  activated from IL  2023
# 37664                                  activated from IL  2023
# 37665                                  activated from IL  2023
# 37666                                  activated from IL  2023
#
# [37667 rows x 7 columns]

# %% [markdown]
# ### Now let's calculate the total sum of injuries for each Year

# %%
data = {}
for year, group in injuryData.groupby('Year'):
    if year > 1989: 
        injuries = group.shape[0]
        data[year] = injuries 
        print(f"Year: {year} Injuries: {injuries}")
        print("---------------------------------------------")
# Out:
# Year: 1990 Injuries: 113
# ---------------------------------------------
# Year: 1991 Injuries: 114
# ---------------------------------------------
# Year: 1992 Injuries: 44
# ---------------------------------------------
# Year: 1993 Injuries: 59
# ---------------------------------------------
# Year: 1994 Injuries: 206
# ---------------------------------------------
# Year: 1995 Injuries: 472
# ---------------------------------------------
# Year: 1996 Injuries: 545
# ---------------------------------------------
# Year: 1997 Injuries: 557
# ---------------------------------------------
# Year: 1998 Injuries: 369
# ---------------------------------------------
# Year: 1999 Injuries: 689
# ---------------------------------------------
# Year: 2000 Injuries: 593
# ---------------------------------------------
# Year: 2001 Injuries: 660
# ---------------------------------------------
# Year: 2002 Injuries: 593
# ---------------------------------------------
# Year: 2003 Injuries: 540
# ---------------------------------------------
# Year: 2004 Injuries: 638
# ---------------------------------------------
# Year: 2005 Injuries: 1158
# ---------------------------------------------
# Year: 2006 Injuries: 1746
# ---------------------------------------------
# Year: 2007 Injuries: 1815
# ---------------------------------------------
# Year: 2008 Injuries: 1617
# ---------------------------------------------
# Year: 2009 Injuries: 1413
# ---------------------------------------------
# Year: 2010 Injuries: 1639
# ---------------------------------------------
# Year: 2011 Injuries: 1112
# ---------------------------------------------
# Year: 2012 Injuries: 1447
# ---------------------------------------------
# Year: 2013 Injuries: 1210
# ---------------------------------------------
# Year: 2014 Injuries: 1274
# ---------------------------------------------
# Year: 2015 Injuries: 1550
# ---------------------------------------------
# Year: 2016 Injuries: 1612
# ---------------------------------------------
# Year: 2017 Injuries: 2205
# ---------------------------------------------
# Year: 2018 Injuries: 1976
# ---------------------------------------------
# Year: 2019 Injuries: 1633
# ---------------------------------------------
# Year: 2020 Injuries: 1066
# ---------------------------------------------
# Year: 2021 Injuries: 2905
# ---------------------------------------------
# Year: 2022 Injuries: 2384
# ---------------------------------------------
# Year: 2023 Injuries: 985
# ---------------------------------------------

# %% [markdown]
# ## It is important to note that the NBA did not have and IR/IL until the 1989-1990 season. Prior to this injured players were still members of the active roster. For this reason, it's likely many injuries do not appear in the dataset.

# %%
print(data)
# Out:
# {1990: 113, 1991: 114, 1992: 44, 1993: 59, 1994: 206, 1995: 472, 1996: 545, 1997: 557, 1998: 369, 1999: 689, 2000: 593, 2001: 660, 2002: 593, 2003: 540, 2004: 638, 2005: 1158, 2006: 1746, 2007: 1815, 2008: 1617, 2009: 1413, 2010: 1639, 2011: 1112, 2012: 1447, 2013: 1210, 2014: 1274, 2015: 1550, 2016: 1612, 2017: 2205, 2018: 1976, 2019: 1633, 2020: 1066, 2021: 2905, 2022: 2384, 2023: 985}

# %%
sns.set(style="darkgrid")
sns.lineplot(x=data.keys(), y=data.values(), data=data)
plt.xlabel('Year')
plt.ylabel('Number of Injuries')
plt.title('Number of Injuries Year by Year')
# Out:
# Text(0.5, 1.0, 'Number of Injuries Year by Year')

# %% [markdown]
# ### We have to encode the data for the "Team" column

# %%
# Encoding each unique team instance
label_encoder = LabelEncoder()
encoded_column = label_encoder.fit_transform(injuryData['Team'])
injuryData['Team'] = encoded_column
unique_values = injuryData['Team'].nunique()
print("Number of unique teams:", unique_values)
# Out:
# Number of unique teams: 44

# %% [markdown]
# ### Let's now remove all rows where the players have been reliquished back from the IL

# %%
# Removing the relinquished column removes all duplicates 
injuryData = injuryData[injuryData['Acquired'].isna()]
del injuryData['Acquired']

# %%
# Out:
#           ID       Date  Team    Relinquished
# 0          0 1951-12-25     5   Don Barksdale  \
# 1          1 1952-12-26    19   Max Zaslofsky
# 2          2 1956-12-29    19   Jim Baechtold
# 3          3 1959-01-16    20    Elgin Baylor
# 4          4 1961-11-26    20    Elgin Baylor
# ...      ...        ...   ...             ...
# 37662  37662 2023-04-16    11             NaN
# 37663  37663 2023-04-16    13             NaN
# 37664  37664 2023-04-16    13             NaN
# 37665  37665 2023-04-16    13             NaN
# 37666  37666 2023-04-16    13             NaN
#
#                                                    Notes  Year
# 0                                           placed on IL  1951
# 1                     placed on IL with torn side muscle  1952
# 2                                placed on inactive list  1956
# 3      player refused to play after being denied a ro...  1959
# 4                      player reported for military duty  1961
# ...                                                  ...   ...
# 37662                                  activated from IL  2023
# 37663                                  activated from IL  2023
# 37664                                  activated from IL  2023
# 37665                                  activated from IL  2023
# 37666                                  activated from IL  2023
#
# [37667 rows x 6 columns]

# %%
filtered_data
# Out:
#           ID       Date  Team Acquired        Relinquished
# 0          0 1951-12-25     5      NaN       Don Barksdale  \
# 1          1 1952-12-26    19      NaN       Max Zaslofsky
# 2          2 1956-12-29    19      NaN       Jim Baechtold
# 3          3 1959-01-16    20      NaN        Elgin Baylor
# 4          4 1961-11-26    20      NaN        Elgin Baylor
# ...      ...        ...   ...      ...                 ...
# 37624  37624 2023-04-09    13      NaN           Ja Morant
# 37625  37625 2023-04-09    13      NaN   Jaren Jackson Jr.
# 37630  37630 2023-04-09    18      NaN     Davion Mitchell
# 37631  37631 2023-04-09    19      NaN        Trevor Keels
# 37633  37633 2023-04-09    34      NaN        Zach Collins
#
#                                                    Notes  Year
# 0                                           placed on IL  1951
# 1                     placed on IL with torn side muscle  1952
# 2                                placed on inactive list  1956
# 3      player refused to play after being denied a ro...  1959
# 4                      player reported for military duty  1961
# ...                                                  ...   ...
# 37624                placed on IL with right hand injury  2023
# 37625                  placed on IL with sore left elbow  2023
# 37630                   placed on IL with sore left knee  2023
# 37631                          placed on IL with illness  2023
# 37633                 placed on IL with lacerated finger  2023
#
# [20044 rows x 7 columns]
